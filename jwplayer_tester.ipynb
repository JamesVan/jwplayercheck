# %%
import datetime
import jwplatform
import logging
import time
import os
import sys
#import moment

# %%
### unicode start date
start_date = 1539993600


####ATTEMPT TO COUNT DAYS FROM TODAY in UNIX ####
# days_ago = 8
# offset = time.time() - mktime()
# dt = datetime.date.today() - datetime.timedelta(days=days_ago)
# start_date = int(time.mktime(dt.timetuple(,tzinfo = dateime.timezone.utc)))

# %%
### Client info ###
jwplatform_client = jwplatform.Client('i8Y1n2VZ', 'RkhiZCEfqWVII9iom6g3g68f')

# %%
def list_videos_missing_params(result_limit=1000):
    timeout_in_seconds = 2
    max_retries = 3
    retries = 0
    offset = 0
    videos = list()

    logging.info("Querying for video list.")
    while True:
        try:
            response = jwplatform_client.videos.list(result_limit=result_limit,
                                                        result_offset=offset,
                                                        start_date=start_date)
        except jwplatform.errors.JWPlatformRateLimitExceededError:
            logging.error("Encountered rate limiting error. Backing off on request time.")
            if retries == max_retries:
                raise jwplatform.errors.JWPlatformRateLimitExceededError()
            timeout_in_seconds *= timeout_in_seconds  # Exponential back off for timeout in seconds. 2->4->8->etc.etc.
            retries += 1
            time.sleep(timeout_in_seconds)
            continue
        except jwplatform.errors.JWPlatformError as e:
            logging.error("Encountered an error querying for videos list.\n{}".format(e))
            raise e
        
        # Reset retry flow-control variables upon a non successful query (AKA not rate limited)
        retries = 0
        timeout_in_seconds = 2

        # Add all fetched video objects to our videos list.
        next_videos = response.get('videos', [])
        last_query_total = response.get('total', 0)
        videos.extend(next_videos)
        offset += len(next_videos)
        logging.info("Accumulated {} videos.".format(offset))
        if offset >= last_query_total:  # Condition which defines you've reached the end of the library
            break
        return(videos)

# %%
tester = list_videos_missing_params(result_limit=5)

# %%
print(tester)
# Out:
# [{'status': 'ready', 'updated': 1536960294, 'expires_date': None, 'description': "\n\nDo you travel a lot? TripIt makes traveling a lot nicer. We cover how, with founder Gregg Brockway but we also talk about other services that'll make working while traveling a lot easier.", 'title': 'Travel Services for Business Travelers', 'views': 4, 'tags': 'default, fastcompany.com, gene brockway, robert scoble, technology, tripit, twistage-bf84e0ac53406, video, work/life, workfast tv', 'sourceformat': None, 'mediatype': 'video', 'upload_session_id': None, 'custom': {'category': 'misc', 'series': 'video', 'batch': '215_migration', 'download_url': 'https://api.twistage.com/videos/bf84e0ac53406/assets/290857/file.mp4', 'thumbnail_url': '', 'legacy_id': 'bf84e0ac53406'}, 'duration': '1806.96', 'sourceurl': None, 'link': 'http://www.fastcompany.com/1690112/travel-services-business-travelers', 'author': 'admin', 'key': 'rq8dhrTH', 'error': None, 'date': 1200712440, 'md5': '088afcc55012896ae2a77716931ab5d7', 'sourcetype': 'file', 'size': '316211753'}, {'status': 'ready', 'updated': 1536588319, 'expires_date': None, 'description': '\n\n', 'title': 'A New Way to do Live TV Production', 'views': 2, 'tags': 'default, fastcompany.com, innovation, newtek, robert scoble, scobleizer tv, switcher, technology, television, tricaster, tv, twistage-3756b0c557aa8, video', 'sourceformat': None, 'mediatype': 'video', 'upload_session_id': None, 'custom': {'category': 'misc', 'series': 'video', 'thumbnail_url': '', 'batch': 'full_migration', 'legacy_id': '3756b0c557aa8'}, 'duration': '1147.38', 'sourceurl': None, 'link': 'http://www.fastcompany.com/1690084/new-way-do-live-tv-production', 'author': 'mansueto-admin', 'key': 'evMfFAvr', 'error': None, 'date': 1206792000, 'md5': '39b2290118337d4b747a5135609c8d99', 'sourcetype': 'file', 'size': '1186974631'}, {'status': 'ready', 'updated': 1536594756, 'expires_date': None, 'description': '\n\nThis video is mind blowing. Well, for Dharmendra S. Modha, manager of cognitive computing at the IBM Almaden Research Center, his job is mind developing. Er, coming up with a computing brain that mimics our own. This is a HUGE challenge and he talks about all the people and organizations that IBM is working with to make this happen.', 'title': 'IBM\'s "Brain" Guy: Dharmendra Modha', 'views': 64, 'tags': 'almaden, artificial intelligence, computing, default, fastcompany.com, ibm, innovation, leadership, research, robert scoble, scobleizer tv, technology, twistage-955c64b06d987, video', 'sourceformat': None, 'mediatype': 'video', 'upload_session_id': None, 'custom': {'category': 'misc', 'series': 'video', 'thumbnail_url': '', 'batch': 'full_migration', 'legacy_id': '955c64b06d987'}, 'duration': '633.60', 'sourceurl': None, 'link': 'http://www.fastcompany.com/1690114/ibms-brain-guy-dharmendra-modha', 'author': 'twistage', 'key': '2Qn8pJqn', 'error': None, 'date': 1208232000, 'md5': '4b005928fd50cceda5634435d35d33b0', 'sourcetype': 'file', 'size': '464597456'}, {'status': 'ready', 'updated': 1536747213, 'expires_date': None, 'description': '\n\n', 'title': 'An Inside Look at CERN’s Large Hadron Collider, Part I', 'views': 18, 'tags': 'cern, default, fastcompany.com, lhc, physics, robert scoble, science, scobleizer tv, technology, twistage-3d19862778b37, video', 'sourceformat': None, 'mediatype': 'video', 'upload_session_id': None, 'custom': {'category': 'misc', 'series': 'video', 'thumbnail_url': '', 'batch': 'full_migration', 'legacy_id': '3d19862778b37'}, 'duration': '1129.37', 'sourceurl': None, 'link': 'http://www.fastcompany.com/1690090/inside-look-cern%E2%80%99s-large-hadron-collider-part-i', 'author': 'mansueto-admin', 'key': 'EkUR7N8a', 'error': None, 'date': 1209009600, 'md5': 'd8042c1b429935ed8e6badf193b00a35', 'sourcetype': 'file', 'size': '1339758629'}, {'status': 'ready', 'updated': 1536816247, 'expires_date': None, 'description': "\n\nYou've seen Digg. You've seen TechMeme. You've seen Google News. But have you seen  N ...

# %%
import json
jsonobject1 = tester[0]
json_category = jsonobject1['custom']['category']
name= "james"
age = 23
print(f'Hello {name}! This is {age}')
f"hello {json_category}"
print(f"this is a test {jsonobject1['custom']['category']} fasldks")
# Out:
# Hello james! This is 23
# this is a test misc fasldks

# %%
def print_video_ids_missing_keys(result_limit=1000):
    video_list = list_videos_missing_params(result_limit=result_limit)
    for each in video_list:
        if each['custom']['series'] is None and each['custom']['category'] is None:
            print(f"Video {each['title']} (key = {each['key']}) is missing both category and series")
            ### Add click to apply function
        elif each['custom']['series'] is None:
            print(f"Video {each['title']} (key = {each['key']}) is missing SERIES custom parameter")
            ### Add click to apply functionif  
        elif each['custom']['category'] is None:
            print(f"Video {each['title']} (key = {each['key']}) is missing the CATEGORY custom parameter")
        else:
            print(f"Video ID = {each['key']} is CATEGORY: {each['custom']['category']} and SERIES: {each['custom']['series']}")
            ### Add click to apply function

# %%
print_video_ids_missing_keys(result_limit=200)
# Out:
# Video ID = rq8dhrTH is CATEGORY: misc and SERIES: video
# Video ID = evMfFAvr is CATEGORY: misc and SERIES: video
# Video ID = 2Qn8pJqn is CATEGORY: misc and SERIES: video
# Video ID = EkUR7N8a is CATEGORY: misc and SERIES: video
# Video ID = S5ufHiFL is CATEGORY: misc and SERIES: video
# Video ID = YgCkAN7s is CATEGORY: misc and SERIES: video
# Video ID = 730VzWa2 is CATEGORY: misc and SERIES: video
# Video ID = EOHdq1lv is CATEGORY: misc and SERIES: video
# Video ID = DqlBGWWn is CATEGORY: misc and SERIES: video
# Video ID = MwLQU3qz is CATEGORY: misc and SERIES: video
# Video ID = F9u7jeQF is CATEGORY: misc and SERIES: video
# Video ID = bAdpUHti is CATEGORY: misc and SERIES: video
# Video ID = qeLZfVuh is CATEGORY: misc and SERIES: video
# Video ID = QOPxvBU2 is CATEGORY: misc and SERIES: video
# Video ID = 9LbM7NNL is CATEGORY: misc and SERIES: video
# Video ID = DVGtjPFs is CATEGORY: misc and SERIES: video
# Video ID = DfKIzgOa is CATEGORY: misc and SERIES: video
# Video ID = 9CPn5H3H is CATEGORY: misc and SERIES: video
# Video ID = EqkbvnpN is CATEGORY: misc and SERIES: video
# Video ID = fpmEDusy is CATEGORY: misc and SERIES: video
# Video ID = 6pcsBSSe is CATEGORY: misc and SERIES: video
# Video ID = 9B1ZWKRx is CATEGORY: misc and SERIES: video
# Video ID = DtxWkpre is CATEGORY: misc and SERIES: video
# Video ID = rUBpqqgo is CATEGORY: misc and SERIES: video
# Video ID = 1qHSeg5I is CATEGORY: misc and SERIES: video
# Video ID = j7X8slDG is CATEGORY: misc and SERIES: video
# Video ID = rmBJwjir is CATEGORY: misc and SERIES: video
# Video ID = FQdxbgTu is CATEGORY: misc and SERIES: video
# Video ID = eIiWAOkE is CATEGORY: misc and SERIES: video
# Video ID = zRlT1Q6b is CATEGORY: misc and SERIES: video
# Video ID = Aik1Eeej is CATEGORY: misc and SERIES: video
# Video ID = Zg75YJfu is CATEGORY: misc and SERIES: video
# Video ID = rTlMJTDu is CATEGORY: misc and SERIES: video
# Video ID = gXTU78aJ is CATEGORY: misc and SERIES: video
# Video ID = nam1Zodu is CATEGORY: misc and SERIES: video
# Video ID = IAoPeAhD is CATEGORY: misc and SERIES: video
# Video ID = O5nLYIOM is CATEGORY: misc and SERIES: video
# Video ID = YPXzFmEU is CATEGORY: misc and SERIES: video
# Video ID = U1Ajg03Y is CATEGORY: misc and SERIES: video
# Video ID = NT0ZS9oc is CATEGORY: misc and SERIES: video
# Video ID = QdakGFXJ is CATEGORY: misc and SERIES: video
# Video ID = AgNCAv4N is CATEGORY: misc and SERIES: video
# Video ID = 1ULOVwAj is CATEGORY: misc and SERIES: video
# Video ID = Hd6f84hW is CATEGORY: misc and SERIES: video
# Video ID = sRkPrsOl is CATEGORY: misc and SERIES: video
# Video ID = mWo0Av7a is CATEGORY: misc and SERIES: video
# Video ID = QADYRepC is CATEGORY: misc and SERIES: video
# Video ID = 6Xa7UewT is CATEGORY: misc and SERIES: video
# Video ID = fJ4Moun3 is CATEGORY: misc and SERIES: video
# Video ID = 2s2beMlU is CATEGORY: misc and SERIES: video
# Video ID = gPkLeX5G is CATEGORY: misc and SERIES: video
# Video ID = yEHogjPk is CATEGORY: misc and SERIES: video
# Video ID = RgPNR5QK is CATEGORY: misc and SERIES: video
# Video ID = mDprXRDi is CATEGORY: misc and SERIES: video
# Video ID = z1KGdyhq is CATEGORY: misc and SERIES: video
# Video ID = MZaqWglG is CATEGORY: misc and SERIES: video
# Video ID = q0drT6S2 is CATEGORY: misc and SERIES: video
# Video ID = W4b2ivDX is CATEGORY: misc and SERIES: video
# Video ID = PvE4Sl4K is CATEGORY: misc and SERIES: video
# Video ID = nY6LAvZK is CATEGORY: misc and SERIES: video
# Video ID = OtjGYByY is CATEGORY: misc and SERIES: video
# Video ID = iPOqIuxn is CATEGORY: misc and SERIES: video
# Video ID = 4T2ei35O is CATEGORY: misc and SERIES: video
# Video ID = mSgOXSli is CATEGORY: misc and SERIES: video
# Video ID = lnzqage4 is CATEGORY: misc and SERIES: video
# Video ID = YNqaPzNv is CATEGORY: misc and SERIES: video
# Video ID = PFTYmuFD is CATEGORY: misc and SERIES: work-smart
# Video ID = NFV1DtpZ is CATEGORY: misc and SERIES: video
# Video ID = RF9edYUg is CATEGORY: misc and SERIES: video
# Video ID = GSxyQJ5a is CATEGORY: misc and SERIES: work-smart
# Video ID = LbodOO5L is CATEGORY: misc and SERIES: video
# Video ID = qjNyuUoA is CATEGORY: misc and SERIES: work-smart
# Video ID = QzQ4zRLC is CATEGORY: misc and SERIES: video
# Video ID = 5vOkVZgW is CATEGORY: misc and SERIES: video
# Video ID = wg36ZDXp is CATEGORY: misc and SERIES: video
# Video ID = uKZMLtoL is CATEGORY: misc and SERIES: video
# Video ID = VGl8yEfd is CATEGORY: misc and SERIES: work-smart
# Video ID = 0PgNXbys is CATEGORY: misc and SERIES: video
# Video ID = 18Mr2m9Z is CATEGORY: misc and SERIES: video
# Video ID = 3hBjfReE is CATEGORY: misc and SERIES: video
# Video ID = L9Nntraz is CATEGORY: misc and SERIES: video
# Video ID = SXNAm81c is CATEGORY: misc and SERIES: video
# Video ID = EsXpc2Ad is CATEGORY: misc and SERIES: video
# Video ID = Dgy9lJx7 is CATEGORY: misc and SERIES: video
# Video ID = 1cIc7z9a is CATEGORY: misc and SERIES: video
# Video ID = wYi3zuri is CATEGORY: misc and SERIES: video
# Video ID = Uwb4KY15 is CATEGORY: misc and SERIES: video
# Video ID = 31ew7Cdf is CATEGORY: misc and SERIES: video
# Video ID = 6hmmKm1M is CATEGORY: misc and SERIES: video
# Video ID = 60IFI1aq is CATEGORY: misc and SERIES: video
# Video ID = 8XDkjP3f is CATEGORY: misc and SERIES: video
# Video ID = 1o39PvK2 is CATEGORY: misc and SERIES: video
# Video ID = zfrdNxqx is CATEGORY: misc and SERIES: video
# Video ID = EKW93KS5 is CATEGORY: misc and SERIES: video
# Video ID = jgR5tCaZ is CATEGORY: misc and SERIES: video
# Video ID = rj6gkz4u is CATEGORY: misc and SERIES: video
# Video ID = onwpvtIm is CATEGORY: misc and SERIES: video
# Video ID = cgkp5atI is CATEGORY: misc and SERIES: video
# Video ID = jEMeXpE8 is CATEGORY: misc and SERIES: video
# Video ID = B4LIagKX is CATEGORY: misc and SERIES: video
# Video ID = t5tlZ1SC is CATEGORY: misc and SERIES: video
# Video ID = GIz5qfog is CATEGORY: misc and SERIES: video
# Video ID = TGGmrW0u is CATEGORY: misc and SERIES: video
# Video ID = mJxbxtCJ is CATEGORY: misc and SERIES: video
# Video ID = welIiA4L is CATEGORY: misc and SERIES: video
# Video ID = K6rkOPfI is CATEGORY: misc and SERIES: video
# Video ID = U3DQfNl1 is CATEGORY: misc and SERIES: video
# Video ID = 1O4XCCHf is CATEGORY: misc and SERIES: video
# Video ID = Yqza7sdd is CATEGORY: misc and SERIES: video
# Video ID = Xmvni30w is CATEGORY: misc and SERIES: video
# Video ID = AODtC6p0 is CATEGORY: misc and SERIES: video
# Video ID = 71yDimEI is CATEGORY: misc and SERIES: video
# Video ID = f2EP9CjK is CATEGORY: misc and SERIES: video
# Video ID = y15TMw1k is CATEGORY: misc and SERIES: video
# Video ID = dirsAycx is CATEGORY: misc and SERIES: video
# Video ID = XXUgDbrM is CATEGORY: misc and SERIES: video
# Video ID = suF6bjew is CATEGORY: misc and SERIES: video
# Video ID = Gu1Efa4D is CATEGORY: misc and SERIES: video
# Video ID = Rv7hTr8w is CATEGORY: misc and SERIES: video
# Video ID = s72ouAhH is CATEGORY: misc and SERIES: video
# Video ID = oyUhS1Pa is CATEGORY: misc and SERIES: video
# Video ID = 2gTSFln6 is CATEGORY: misc and SERIES: video
# Video ID = jJpYapcm is CATEGORY: misc and SERIES: work-smart
# Video ID = HwWcyRC2 is CATEGORY: misc and SERIES: video
# Video ID = vwe9Nsvj is CATEGORY: misc and SERIES: video
# Video ID = 1NJioE1f is CATEGORY: misc and SERIES: video
# Video ID = NKuLtZPL is CATEGORY: misc and SERIES: video
# Video ID = U2WpIckh is CATEGORY: misc and SERIES: video
# Video ID = geIzNjz2 is CATEGORY: misc and SERIES: video
# Video ID = 0yXnf4Yy is CATEGORY: misc and SERIES: video
# Video ID = 2ODCXPUp is CATEGORY: misc and SERIES: video
# Video ID = MJX3Fvnr is CATEGORY: misc and SERIES: video
# Video ID = oPPE4agh is CATEGORY: misc and SERIES: video
# Video ID = Cc8iyUTj is CATEGORY: misc and SERIES: video
# Video ID = i3cfyoZA is CATEGORY: misc and SERIES: video
# Video ID = bzu1i8CR is CATEGORY: misc and SERIES: video
# Video ID = ni6hk8V2 is CATEGORY: misc and SERIES: video
# Video ID = A9qSyPdk is CATEGORY: misc and SERIES: video
# Video ID = lk5r4csA is CATEGORY: misc and SERIES: video
# Video ID = D7MdHGh9 is CATEGORY: misc and SERIES: video
# Video ID = scH2ptVi is CATEGORY: misc and SERIES: video
# Video ID = I2s4D4Gp is CATEGORY: misc and SERIES: video
# Video ID = ZtcfqI7M is CATEGORY: misc and SERIES: video
# Video ID = rUThbRO9 is CATEGORY: misc and SERIES: video
# Video ID = 0lKGeVvv is CATEGORY: misc and SERIES: video
# Video ID = xTetfHq7 is CATEGORY: misc and SERIES: video
# Video ID = FM68zmHw is CATEGORY: misc and SERIES: video
# Video ID = Z6eOQYFh is CATEGORY: misc and SERIES: video
# Video ID = YxmYfVQ5 is CATEGORY: misc and SERIES: video
# Video ID = 2TmCPp8y is CATEGORY: misc and SERIES: video
# Video ID = HQKJjFyL is CATEGORY: misc and SERIES: video
# Video ID = BDNtZ30x is CATEGORY: misc and SERIES: video
# Video ID = hjOgI7PE is CATEGORY: misc and SERIES: video
# Video ID = KtD7VzZY is CATEGORY: misc and SERIES: video
# Video ID = AQgwWMQX is CATEGORY: misc and SERIES: video
# Video ID = 8mAPAfGw is CATEGORY: misc and SERIES: video
# Video ID = 3JeUHr9W is CATEGORY: misc and SERIES: video
# Video ID = 4jlrj77j is CATEGORY: misc and SERIES: video
# Video ID = DTTiQtDV is CATEGORY: misc and SERIES: video
# Video ID = tL1PfwiT is CATEGORY: misc and SERIES: video
# Video ID = 7Zf3WtRB is CATEGORY: misc and SERIES: video
# Video ID = LrxPg4h4 is CATEGORY: misc and SERIES: video
# Video ID = Am2HGCqE is CATEGORY: misc and SERIES: video
# Video ID = llAnWbRm is CATEGORY: misc and SERIES: video
# Video ID = KUiKjyBJ is CATEGORY: misc and SERIES: video
# Video ID = yO8VfFFe is CATEGORY: misc and SERIES: video
# Video ID = 2fht3KJ0 is CATEGORY: misc and SERIES: video
# Video ID = R8CsmC7c is CATEGORY: misc and SERIES: video
# Video ID = 5eMcdNw1 is CATEGORY: misc and SERIES: video
# Video ID = RyvOiboo is CATEGORY: misc and SERIES: video
# Video ID = 7E4jrvnP is CATEGORY: misc and SERIES: video
# Video ID = seRTJPy1 is CATEGORY: misc and SERIES: video
# Video ID = Qjr7ybLI is CATEGORY: misc and SERIES: video
# Video ID = xFickqTz is CATEGORY: misc and SERIES: video
# Video ID = seGmApOb is CATEGORY: misc and SERIES: video
# Video ID = bWSHuUNK is CATEGORY: misc and SERIES: video
# Video ID = 339z26BV is CATEGORY: misc and SERIES: video
# Video ID = CZWuw1xa is CATEGORY: misc and SERIES: video
# Video ID = 3RTRHNdQ is CATEGORY: misc and SERIES: video
# Video ID = YIS0eBBR is CATEGORY: misc and SERIES: video
# Video ID = vYNe87JT is CATEGORY: misc and SERIES: video
# Video ID = 6VSTHz9E is CATEGORY: misc and SERIES: video
# Video ID = 9XjfB8io is CATEGORY: misc and SERIES: video
# Video ID = W853ihJL is CATEGORY: misc and SERIES: video
# Video ID = 6Bb9z6Gv is CATEGORY: misc and SERIES: video
# Video ID = Prc60n5h is CATEGORY: misc and SERIES: video
# Video ID = gPmhPUvK is CATEGORY: misc and SERIES: video
# Video ID = lGhlJ6l5 is CATEGORY: misc and SERIES: video
# Video ID = 2qKS32fB is CATEGORY: misc and SERIES: video
# Video ID = qv2qKKdp is CATEGORY: misc and SERIES: video
# Video ID = XSoSyNTq is CATEGORY: misc and SERIES: video
# Video ID = 3CLnVkfg is CATEGORY: misc and SERIES: video
# Video ID = 8dKlB4hJ is CATEGORY: misc and SERIES: video
# Video ID = RO1tru1e is CATEGORY: misc and SERIES: video
# Video ID = oVIuu3Ol is CATEGORY: misc and SERIES: video
# Video ID = RRGbmJeZ is CATEGORY: misc and SERIES: video
# Video ID = dzhROGyk is CATEGORY: misc and SERIES: video
# Video ID = aiHu91xo is CATEGORY: misc and SERIES: video
# Video ID = vQfcWExC is CATEGORY: misc and SERIES: video
# Video ID = Wunz7HnL is CATEGORY: misc and SERIES: video
